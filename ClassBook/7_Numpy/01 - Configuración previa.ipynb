# %% [markdown]
# # Configuración previa
#
# El análisis de datos básico en Python se realiza utilizando tres bibliotecas que se complementan perfectamente entre ellas:
#
# - **NumPy**: Para manejar **arrays**.
# - **Pandas**: Para manejar **dataframes**.
# - **Matplotlib**: Para visualizar **gráficos**.
#
# Son externas a Python por lo que tenemos que instalarlas para poder utilizarlas:
#
# ```bash
# pip install numpy pandas
# pip install -U matplotlib # -U es un argumento que le indica que realice un upgrade
# ```
#
# También se puede instalar desde el propio `Jupyter Notebook` con una exclamación delante:
#
# ```bash
# !pip install numpy pandas matplotlib
# ```
#
# Tardará un rato en ejecutar la celda pero veremos el resultado:

# %%
# %pip install numpy pandas matplotlib
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in c:\users\ajmen\appdata\local\programs\python\python312\lib\site-packages (1.26.4)
# Requirement already satisfied: pandas in c:\users\ajmen\appdata\roaming\python\python312\site-packages (2.2.2)
# Requirement already satisfied: matplotlib in c:\users\ajmen\appdata\local\programs\python\python312\lib\site-packages (3.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ajmen\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ajmen\appdata\roaming\python\python312\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ajmen\appdata\roaming\python\python312\site-packages (from pandas) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ajmen\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ajmen\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ajmen\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ajmen\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\ajmen\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\ajmen\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ajmen\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\ajmen\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
